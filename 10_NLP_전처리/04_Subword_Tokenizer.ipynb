# %% [markdown]
# # 형태소 분석 기반 토큰화의 문제
# - 형태소 분석기는 작성된 알고리즘 또는 학습된 내용을 바탕으로 토큰화를 하기 때문에 오탈자나 띄어쓰기 실수, 신조어, 외래어, 고유어 등이 사용된 경우 제대로 토큰화 하지 못한다.
# - 그래서 발생 할 수있는 잠재적 문제점
#     - 어휘사전을 크게 만든다.
#         - 같은 의미의 단어가 형태소 분석이 안되어 여러개 등록될 수있다.
#         - ex) 신조어 `돈쭐` 이라는 단어를 인식 못할 경우 `"돈쭐내러", "돈쭐나", "돈쭐냄"` 등이 다 등록 될 수 있다.
#     - OOV(Out Of Vocab)에 대응하기 어렵게 만든다.
#         - 같은 어근의 단어가 있지만 조사등이 바뀐 신조어등을 OOV로 인식할 수있다.
#
#
#
#
# > ### 어휘 사전(Vocabulary)과 Out Of Vocabulary (OOV)
# >
# > - 언어 모델링에서 **어휘 사전(Vocabulary)**은 모델이 처리할 수 있는 단어(토큰)들의 집합이다.
# > - 어휘 사전은 보통 전체 데이터셋을 토큰화한 후, 각 토큰을 고유한 정수 인덱스로 매핑해 만든다.
# >    - 매핑된 정수는 모델에 입력되는 텍스트 데이터를 숫자 형식으로 변환해 모델이 처리할 수 있도록 돕는다.
# >    - 예시) {"I": 1, "he": 2, "you": 3, ...}
# > - **Out Of Vocabulary (OOV)**
# >    - 어휘 사전(Vocab): 코퍼스를 구성하는 모든 토큰의 집합.
# >    - **OOV**란 어휘 사전에 포함되지 않은 토큰을 의미하며, 모델이 해당 토큰을 처리할 수 없기 때문에 일반적으로 특별한 토큰(예: `[UNK]`)으로 대체되거나 다른 방식으로 처리된다.

# %% [markdown]
# # Subword Tokenization(하위 단어 토큰화)
#
# ## 정의
#
# - Subword Tokenization은 단어를 더 작은 단위(subword)로 나누어 텍스트를 토큰화하는 방식이다.
#     - subword는 하나의 단어를 구성하는 단어들을 말한다.(coworker: co, work, er)
# - 주로 자주 등장하는 단어의 일부를 공통된 토큰으로 만들고, 희귀하거나 복합적인 단어는 작은 조각(subword)으로 나누어 처리한다.
# - 단어 자체를 그대로 사용하기보다는 단어의 일부를 나누어 처리함으로써 새로운 단어나 미등록 단어(Out-of-Vocabulary) 문제를 줄일 수 있다.
#
# ## 장점
#
# 1. **미등록 단어 처리 가능**
#    -  새로운 단어(신조어, 속어, 고유어등)가 등장해도 미리 정의된 subword를 조합해서 표현할 수 있어 OOV 문제를 줄일 수 있다.
#
# 2. **어휘 크기 축소**
#    - 같은 subword를 여러 단어에서 공유함으로써, 완전한 단어를 사용하는 경우보다 어휘집의 크기를 작게 유지할 수 있다.
#
#
# ## 종류
#
# 1. **Byte-Pair Encoding (BPE)**
#    - 자주 등장하는 문자 쌍을 반복적으로 병합해 서브워드를 생성하는 방식.
#    - OpenAI의 GPT 모델에 사용된 토크나이저이다.
#    - 각 어절 단위로 분리 후, 조합 (빈도수)
#
# 2. **Unigram**
#    - 빈도기반 확률모델에 따라 subword 단위를 선택하는 방식이다.
#    - BPE보다 유연하여 더 다양한 분할 결과를 얻을 수 있다.
#    - 모든 경우의수 조합 후, 확률이 낮은 것부터 제거
#
# 3. **WordPiece**
#    - BPE와 유사하지만, 빈도수가 아니라, 가능성이 높은 조합(합쳐질 가능성이 높은 subword)에 기반해 subword들을 찾는다.
#    - Google의 BERT 모델에 사용된 토크나이저이다.
#    - 각 어절 단위로 분리, 조합 (확률개념)

# %% [markdown]
# # Byte Pair Encoding 방식
#
# - 원래 Text data 압축을 위해 만들어진 방법으로 text 에서 많이 등장하는 두글자 쌍의 조합을 찾아 부호화하는 알고리즘이다.
# - 연속된 글자 쌍이 더 나타나지 않거나 정해진 어휘사전 크기에 도달 할 때 까지 조합을 찾아 부호화 하는 작업을 반복한다.
#
# ## text 압축 방식의 예
# - 원문: abracadabra
# 1. AracadAra: ab -> A :=> 원문에서 가장 빈도수 많은 ab를 A(부호로 아무 글자나 사용할 수 있다.)로 치환
# 2. ABcadAB: ra -> B :=> 1에서 가장 빈도수가 많은 ra를 B로 치환
# 3. CcadC: AB -> C :=> 2에서 가장 빈도수 맣은 AB를 C로 치환한다.(치환된 글자 쌍도 변환대상에 포함된다.)
#
# ## BPE Tokenizer 방식
# BPE 토크나이저는 자주 등장하는 글자 쌍을 찾아 치환하는 대신 **단어 사전**에 추가한다.
#
# ### 예)
# 1. 말뭉치의 토큰들의 빈도수, 어휘사전은 아래와 같을 경우
#     - 빈도사전: ('low', 5), ('lower', 2), ('newest', 6), ('widest', 3)
#     - 어휘사전: ['low', 'lower', 'newest', 'widest']
# 2. 빈도 사전내의 모든 단어들을 글자 단위로 나눈다. (Pre Tokenization)
#     - 빈도사전: ('l', 'o', 'w',  5), ('l', 'o', 'w', 'e', 'r', 2), ('n', 'e', 'w', 'e', 's', 't', 6), ('w', 'i', 'd', 'e', 's', 't', 3)
#     - 어휘사전: ['d', 'e', 'i', 'l', 'n', 'o', 'r', 's', 't', 'w']
# 3. 빈도 사전을 기준으로 가장 자주 등장하는 글자 쌍(byte pair)를 찾는다.  위에서는 **'e'와 's'가 총 9번으로 가장 많이 등장함**. 'e'와 's'를 'es'로 합치고 어휘 사전에 추가한다.
#     - 빈도사전: ('l', 'o', 'w',  5), ('l', 'o', 'w', 'e', 'r', 2), ('n', 'e', 'w', **'es'**, 't', 6), ('w', 'i', 'd', **'es'**, 't', 3)
#     - 어휘사전: ['d', 'e', 'i', 'l', 'n', 'o', 'r', 's', 't', 'w', **'es'**]
# 4. 3 번의 과정을 계속 반복한다. 빈도수가 가장 많은 'es'와 't' 쌍을 'est'로 병합하고 'est'를 어휘 사전에 추가한다.
#     - 빈도사전: ('l', 'o', 'w',  5), ('l', 'o', 'w', 'e', 'r', 2), ('n', 'e', 'w', **'est'**, 6), ('w', 'i', 'd', **'est'**, 3)
#     - 어휘사전: ['d', 'e', 'i', 'l', 'n', 'o', 'r', 's', 't', 'w', **'es'**, **'est'**]
# 5. 만약 10번 반복했다고 하면 다음과 같은 빈도 사전과 어휘 사전이 생성된다.
#     - 빈도 사전: (**'low'**, 5), (**'low'**, 'e', 'r', 2), ('n', 'e', 'w', **'est'**, 6), ('w', 'i', 'd', **'est'**, 3)
#     - 어휘사전: ['d', 'e', 'i', 'l', 'n', 'o', 'r', 's', 't', 'w', **'es'**, **'est'**, **'lo'**,**'low'**, **'low'**, **'ne'**, **'new'**, **'newest'**, **'wi'**, **'wid'**, **'widest'**]
#
# - 위와 같이 어휘 사전이 만들어 지면 원래 어휘서전에 없던 것들에 대한 처리를 할 수있다.
#     - ex)
#         - 'newer' :=> 'new', 'e', 'r',
#         - 'lowest' :=> 'low', 'est'
#         - 'wider' :=> 'wid', 'e', 'r'

# %% [markdown]
# # WordPiece tokenizer
#
# - Byte Pair Encoding 이 빈도 기반이라면 wordpiece tokenizer는 확률 기반으로 글자 쌍을 병합한다.
# - 두개 글자 쌍의 빈도수를 각 개별 글자 빈도수의 곱으로 나눈 점수가 가장 높은 순서대로 글자쌍을 묶어 나간다.
#
# $$
# score = \cfrac{f(x, y)}{f(x)\cdot f(y)}
# $$
#
# 함수 f는 빈도를 나타내며 x, y는 병합하려는 하위 단어이다.
#
# - 빈도사전: ('l','o','w', 5), ('l','o','w', 'e', 'r', 2), ('n', 'e', 'w', 'e', 's', 't', 6), ('w', 'i', 'd', 'e', 's', 't', 3)
# - 어휘사전: ('d', 'e', 'i', 'l', 'n', 'o', 'r', 's', 't', 'w')
# - 가장 빈도수가 높은 쌍은 'e','s'로 9번 등장한다. 이때 각 글자는 전체에서 각각 'e'는 17번, 's'는 9번 등장한다. 위 공식에 대입하면 score는 $\frac{9}{17 \times 9} \approx 0.06$ 이다.
# - 'i'와 'd' 쌍은 3번만 등장하지만 전체에서 각각 'i' 3번, 'd' 3번 등장한다. 그래서 score는 $\frac{3}{3 \times 3} \approx 0.33$ 이다.
# - 나타난 빈도수는 'es' 가 많치만 더 높은 score를 가지는 'id' 쌍을 병합한다.
# - 빈도사전: ('l','o','w', 5), ('l','o','w', 'e', 'r', 2), ('n', 'e', 'w', 'e', 's', 't', 6), ('w', **'id'**, 'e', 's', 't', 3)
# - 어휘사전: ('d', 'e', 'i', 'l', 'n', 'o', 'r', 's', 't', 'w', **'id'**)
# 위의 작업을 반복해 연속된 글자 쌍이 더이상 나타나지 않거나 어휘 사전 max 크기에 도달할 때 까지 학습한다.

# %% [markdown]
# # Unigram 방식
# - 빈도 기반 확률 모델을 사용하여 효율적으로 서브워드를 선택하고, 불필요한 서브워드를 제거해 최적의 어휘 크기를 찾는 알고리즘
#
#
# - **초기 어휘 집합 구성**
#     - 대상 text에 모든 단어와 그 서브스트링을 포함한 어휘 집합을 생성한다. 이 어휘 집합은 나올 수있는 모든 subword들을 다 모아놓은 것이다.
#     - 예를 들어 "hug" 단어의  ["h", "u", "g", "hu", "ug", "hug"]  substring을 만든다. 이들이 subword 후보가 된다.
# - **각 Subword의 빈도수 기반 확률 계산**
#     -  $\cfrac{subword가\;나타난\;횟수}{전체\;빈도수}$ 로 각 subword들의 나타난 확률을 계산한다.
# - **가능한 분할에 대한 확률 계산**
#     - 단어를 여러 서브워드로 분할할 수 있는 경우, 각 분할에 대한 전체 확률을 계산한다.
#     - 확률 계산은 $ P(subword1)\;\times \; P(subword2)\;\times\; ..$ 으로 계산한다.
#     - 예를 들어 "hug" 를 분할 한다고 했을 때
#         1. \["h", "u", "g"\]: $ P(h) \times P(u) \times P(g) $
#         2. \["hu", "g"\]: $ P(pu) \times P(g) $
#
#    - 각각의 확률을 계산한 후, **가장 높은 확률**을 가진 분할을 선택한다.
#      - 위 예에서 만약 1의 확률이 0.01 이고 2의 확률이 0.00001 이라면 첫번째 분할이 선택된다.
#
# - **서브워드 제거**
#     - 위의 훈견과정에서 불필요한 서브워드를 제거하면서 최적의 어휘 집합을 찾아간다.
#     - 제거 대상은 빈도수가 낮거나 조합에 크게 영향을 주지 않은 subword들이다.

# %%
from Korpora import Korpora

corpus = Korpora.load("korean_petitions")
# Out:
#     Korpora 는 다른 분들이 연구 목적으로 공유해주신 말뭉치들을
#     손쉽게 다운로드, 사용할 수 있는 기능만을 제공합니다.
#
#     말뭉치들을 공유해 주신 분들에게 감사드리며, 각 말뭉치 별 설명과 라이센스를 공유 드립니다.
#     해당 말뭉치에 대해 자세히 알고 싶으신 분은 아래의 description 을 참고,
#     해당 말뭉치를 연구/상용의 목적으로 이용하실 때에는 아래의 라이센스를 참고해 주시기 바랍니다.
#
#     # Description
#     Author : Hyunjoong Kim lovit@github
#     Repository : https://github.com/lovit/petitions_archive
#     References :
#
#     청와대 국민청원 게시판의 데이터를 월별로 수집한 것입니다.
#     청원은 게시판에 글을 올린 뒤, 한달 간 청원이 진행됩니다.
#     수집되는 데이터는 청원종료가 된 이후의 데이터이며, 청원 내 댓글은 수집되지 않습니다.
#     단 청원의 동의 개수는 수집됩니다.
#     자세한 내용은 위의 repository를 참고하세요.
#
#     # License
#     CC0 1.0 Universal (CC0 1.0) Public Domain Dedication
#     Details in https://creativecommons.org/publicdomain/zero/1.0/
# [korean_petitions] download petitions_2017-08: 1.84MB [00:00, 3.08MB/s]
# [korean_petitions] download petitions_2017-09: 20.4MB [00:02, 9.99MB/s]
# [korean_petitions] download petitions_2017-10: 12.0MB [00:03, 3.35MB/s]
# [korean_petitions] download petitions_2017-11: 28.4MB [00:01, 23.9MB/s]
# [korean_petitions] download petitions_2017-12: 29.0MB [00:01, 23.1MB/s]
# [korean_petitions] download petitions_2018-01: 43.9MB [00:17, 2.58MB/s]
# [korean_petitions] download petitions_2018-02: 33.8MB [00:21, 1.58MB/s]
# [korean_petitions] download petitions_2018-03: 34.3MB [00:18, 1.88MB/s]
# [korean_petitions] download petitions_2018-04: 35.5MB [00:09, 3.56MB/s]
# [korean_petitions] download petitions_2018-05: 37.5MB [00:16, 2.31MB/s]
# [korean_petitions] download petitions_2018-06: 37.8MB [00:29, 1.30MB/s]
# [korean_petitions] download petitions_2018-07: 40.5MB [00:29, 1.39MB/s]
# [korean_petitions] download petitions_2018-08: 39.8MB [00:36, 1.10MB/s]
# [korean_petitions] download petitions_2018-09: 36.1MB [00:22, 1.61MB/s]
# [korean_petitions] download petitions_2018-10: 38.1MB [00:23, 1.62MB/s]
# [korean_petitions] download petitions_2018-11: 37.7MB [00:15, 2.49MB/s]
# [korean_petitions] download petitions_2018-12: 33.0MB [00:07, 4.18MB/s]
# [korean_petitions] download petitions_2019-01: 34.8MB [00:03, 11.0MB/s]
# [korean_petitions] download petitions_2019-02: 30.8MB [00:04, 6.27MB/s]
# [korean_petitions] download petitions_2019-03: 34.9MB [00:02, 15.2MB/s]

# %%
petitions = corpus.get_all_texts() # 청원 데이터를 반환. list[str] str: 개별 청원
len(petitions)
# Out:
# 433631

# %%
print(petitions[0])
# Out:
# 안녕하세요. 현재 사대, 교대 등 교원양성학교들의 예비교사들이 임용절벽에 매우 힘들어 하고 있는 줄로 압니다. 정부 부처에서는 영양사의 영양'교사'화, 폭발적인 영양'교사' 채용, 기간제 교사, 영전강, 스강의 무기계약직화가 그들의 임용 절벽과는 전혀 무관한 일이라고 주장하고 있지만 조금만 생각해보면 전혀 설득력 없는 말이라고 생각합니다. 학교 수가 같고, 학생 수가 동일한데 영양교사와 기간제 교사, 영전강 스강이 학교에 늘어나게 되면 당연히 정규 교원의 수는 줄어들게 되지 않겠습니까? 기간제 교사, 영전강, 스강의 무기계약직화, 정규직화 꼭 전면 백지화해주십시오. 백년대계인 국가의 교육에 달린 문제입니다. 단순히 대통령님의 일자리 공약, 81만개 일자리 창출 공약을 지키시고자 돌이킬 수 없는 실수는 하지 않으시길 바랍니다. 세계 어느 나라와 비교해도, 한국 교원의 수준과 질은 최고 수준입니다. 고등교육을 받고 어려운 국가 고시를 통과해야만 대한민국 공립 학교의 교단에 설 수 있고, 이러한 과정이 힘들기는 하지만 교원들이 교육자로서의 사명감과 자부심을 갖고 교육하게 되는 원동력이기도 합니다. 자격도 없는 비정규 인력들을 일자리 늘리기 명목 하에 학교로 들이게 되면, 그들이 무슨 낯으로 대한민국이 '공정한 사회' 라고 아이들에게 가르칠 수 있겠습니까? 그들이 가르치는 것을 학부모와 학생들이 납득할 수 있겠으며, 학생들은 공부를 열심히 해야하는 이유를 찾을 수나 있겠습니까? 열심히 안 해도 떼 쓰면 되는 세상이라고 생각하지 않겠습니까? 영양사의 영양교사화도 재고해주십시오. 영양사분들 정말 너무나 고마운 분들입니다. 학생들의 건강과 영양? 당연히 성장기에 있는 아이들에게 필수적이고 중요한 문제입니다. 하지만 이들이 왜 교사입니까. 유래를 찾아 볼 수 없는 영양사의 '교사'화. 정말 대통령님이 생각하신 아이디어라고 믿기 싫을 정도로 납득하기 어렵습니다. 중등은 실과교과 교사가 존재하지요? 초등 역시 임용 시험에 실과가 포함돼 있으며 학교 현장에서도 정규 교원이 직접 실과 과목을 학생들에게 가르칩니다. 영양'교사', 아니 영양사가 학생들에게 실과를 가르치지 않습니다. 아니 그 어떤 것도 가르치지 않습니다. 올해 대통령님 취임 후에 초등, 중등 임용 티오가 초전박살 나는 동안 영양'교사' 티오는 폭발적으로 확대된 줄로 압니다. 학생들의 교육을 위해 정말 교원의 수를 줄이고, 영양 교사의 수를 늘리는 것이 올바른 해답인지 묻고 싶습니다. 마지막으로 교원 당 학생 수. 이 통계도 제대로 내주시기 바랍니다. 다른 나라들은 '정규 교원', 즉 담임이나 교과 교사들로만 통계를 내는데(너무나 당연한 것이지요) 왜 한국은 보건, 영양, 기간제, 영전강, 스강 까지 다 포함해서 교원 수 통계를 내는건가요? 이런 통계의 장난을 통해 OECD 평균 교원 당 학생 수와 거의 비슷한 수준에 이르렀다고 주장하시는건가요? 학교는 교육의 장이고 학생들의 공간이지, 인력 센터가 아닙니다. 부탁드립니다. 부디 넓은 안목으로 멀리 내다봐주시길 간곡히 부탁드립니다.

# %%
# 파일로 저장
save_petitions_path = "./data/petitions_corpus.txt"
with open(save_petitions_path, 'wt', encoding = 'utf-8') as fw:
    for p in petitions:
        fw.write(p + "\n")

# %%
# 저장된 txt 읽기
with open(save_petitions_path, 'rt', encoding = 'utf-8') as fr:
    petitions_txt = fr.read()

# %% [markdown]
# # Hugging Face tokenizers 패키지 사용해 토큰화 수행
# - Subword tokenization을 처리하는 다양한 패키지(라이브러리)가 있다.
#
# ## 주요 라이브러리
# - [tokenizers](https://huggingface.co/docs/tokenizers/index)
#     - huggingface에서 개발한 tokenizer 라이브러리로 BPE, WordPiece, Unigram 알고리즘을 지원한다.
#     - 설치: `pip install tokenizers`
# - [Sentencepiece](https://github.com/google/sentencepiece)
#     - 구글에서 개발한 subword tokenizer 라이브러리로 BPE, Unigram 방식 지원.
#     - 설치: `pip install sentencepiece`

# %% [markdown]
# > ### korpora 말뭉치
# > - 다양한 한글 데이터셋을 제공하는 패키지
# > - `pip install korpora`

# %% [markdown]
# ## Hugging Face tokenizers 패키지이용
#
# - 설치: `pip install tokenizers`
# - Tokenizer 생성
#     - 토큰화 알고리즘을 지정해 instance 생성.
# - Trainer 생성
#     - 학습 파라미터를 설정해서 instance 생성
# - Tokenizer 학습
#     - train() 메소드: 학습 text 파일 경로를 지정해서 학습
#     - train_from_iterator() 메소드: 학습할 string들을 iterator를 통해 제공.
# - https://github.com/huggingface/tokenizers

# %%
import time
# Tokenizer
from tokenizers import Tokenizer 
from tokenizers.models import BPE
# subword 알고리즘을 적용하기 전에 어떻게 나눠놓을 것인지.
from tokenizers.pre_tokenizers import Whitespace
# Trainer (학습)
from tokenizers.trainers import BpeTrainer

# 토크나이저 생성
# subword 알고리즘을 구현한 Tokenizer의 객체를 넣어 생성. (BPE)
# unk_token : OOV(out of voc)(unknown) 단어(토큰)을 처리할 토큰을 지정.
tokenizer = Tokenizer(BPE(unk_token= '[UNK]'))
# pre tokenizer를 등록
tokenizer.pre_tokenizer = Whitespace() # 공백을 기준으로 미리 토큰화하여 놓는다.
# tokenzer를 학습하는 Trainer 객체 -> tokenizer 알고리즘 별로 Trainer클래스가 제공됨.
# initalizer에 어떻게 학습시킬지 설정
trainer = BpeTrainer(
    vacab_size = 10000, # 어휘사전의 최대 크기(고유 토큰의 최대 갯수) / 보통 30000개 정도 설정
    min_frequency = 10, 
    # 사전에 넣을 토큰의 **최소 출연 횟수**(빈도수) -> 어떤 토큰을 사전에 등록 할 때 n번 이상 출현해야 사전에 등록 ex) ab / 5번 -> 사전미등록
    special_tokens = ["[UNK],", "[PAD]"]
    # 어휘사전에 추가할 특수토큰(special token)들 지정. 이중 unk_token은 반드시 설정.

)

# special token : (토큰이름은 자율적으로 지정해도 상관없지만 필요한 토큰을 용도에 맞게 사용)
# [UNK] - oov 토큰을 표시. 
# [PAD] - 문장의 토큰수를 맞추기 위한 padding.(자릿수 맞추기 위한 용도)
# [CLS] - 문장의 시작을 표시 + 전체 문장의 의미를 저장하는 토큰으로 사용(BERT모델에서 주로 사용).
# [SOS] - 문서의 시작을 표시.
# [EOS] - 문서의 끝을 표시.
# [SEP] - 문서가 여러 문장으로 구성된 경우 문장을 구분하는 용도.
# [MASK] - 일부 토큰을 가리는 토큰.(기존 토큰을 대체하여 삽입.) -> LLM 모델중 감춰진 부분을 맞춰가며 학습하는 모델이 존재.

# [PAD] 예시 / 입력데이터 - 5개의 토큰으로 통일 -> 4개 이하의 토큰은 [PAD] 토큰으로 채우고, 6개 이상은 뒷 토큰들 제거하는 방식으로 구성

# %%
# 학습 - corpus를 받아서 어휘사전을 만드는 작업.
s = time.time()
tokenizer.train(["data/petitions_corpus.txt"], trainer=trainer) # 학습시킬 파일 경로(들), trainer 객체
e = time.time()
print("걸린 시간 : ", (e-s), "초")
# Out:
# 걸린 시간 :  114.5571174621582 초

# %%
# 학습된 tokenizer를 disk에 저장.
import os
os.makedirs("saved_models", exist_ok = True)

# 저장 - tokenizer.save(경로)
save_path = "saved_models/petitions_bpe.json"
tokenizer.save(save_path)

# %%
# 저장된 모델 load
load_tokenizer = Tokenizer.from_file(save_path)

# %%
# vocab size
print("vocab size(어휘사전에 어휘수) : ", load_tokenizer.get_vocab_size())
# Out:
# vocab size(어휘사전에 어휘수) :  30000

# %%
tokenizer.get_vocab() # 어휘사전을 dictionary로 반환(key : 단어, value : id)
# Out:
# {'뗫': 4853,
#  '때문이라고': 18525,
#  '자라는': 16117,
#  '기사입니다': 25398,
#  '취지와': 28488,
#  '신분증': 17675,
#  '廷': 1969,
#  '객': 3926,
#  'ta': 19435,
#  '올해': 9678,
#  '맞고': 13561,
#  '4년제': 20956,
#  '죽음에': 24577,
#  '벤츠': 27279,
#  '전기': 9353,
#  '跆': 3480,
#  '类': 2994,
#  '해수': 26370,
#  '보았을': 26595,
#  '전수조사를': 28970,
#  '117': 29082,
#  '가상화폐': 9178,
#  '힘없고': 19967,
#  '난민으로': 28832,
#  '평에': 29613,
#  '대놓고': 14817,
#  '擲': 2231,
#  '누락': 17079,
#  '‟': 472,
#  '2기': 28814,
#  '이은': 22033,
#  '싫': 5921,
#  '室': 1813,
#  '누구는': 14375,
#  '만도': 19193,
#  ')"': 27553,
#  '新': 2271,
#  '흡수': 21789,
#  '좋겠다': 17120,
#  '휙': 7612,
#  '낮고': 24629,
#  '猾': 2725,
#  '숙여': 29778,
#  '앛': 6091,
#  '룬': 5068,
#  '뇔': 4481,
#  '선수들에게': 21667,
#  '핷': 7449,
#  'ろ': 970,
#  '迹': 3545,
#  '했으나': 11005,
#  '얼어': 27236,
#  '책임지지': 27071,
#  '몡': 5237,
#  '소득분위': 29283,
#  '피해자들의': 18793,
#  'べ': 950,
#  '강남구': 27189,
#  '우체국': 21308,
#  '정보를': 10520,
#  '이런식으로': 12348,
#  '껏': 4211,
#  '北': 1494,
#  '렺': 5020,
#  '따른': 9431,
#  '외국의': 20927,
#  '❻': 821,
#  '사립유치원': 14503,
#  '시점에': 14937,
#  '비판하는': 26306,
#  '우방': 28473,
#  '인고의': 29940,
#  '는지는': 23764,
#  '일반인': 14520,
#  '讀': 3389,
#  '간이': 18521,
#  '대상입니다': 26420,
#  '사퇴': 11826,
#  '가맹': 15857,
#  '착복': 29108,
#  '나라냐': 16528,
#  '그렇다고': 10944,
#  '만원씩': 21416,
#  '아주머니': 22525,
#  '할것입니다': 12032,
#  '\ue75d': 7681,
#  '20만': 12847,
#  '자료': 9492,
#  '훼': 7605,
#  '쌘': 5953,
#  '가지고있는': 28793,
#  '질에': 21455,
#  '말한다': 15720,
#  '슐': 5883,
#  '부어': 23120,
#  '임용': 11584,
#  '시민이': 15463,
#  '띡': 4933,
#  '세부': 17020,
#  '취하지': 19600,
#  '들어': 8249,
#  '이러니': 17685,
#  '자가': 8333,
#  '딱히': 21721,
#  '안보고': 22988,
#  '근처에': 18986,
#  'р': 256,
#  '着': 2854,
#  '쓸데없는': 17437,
#  '민원은': 19317,
#  '편하게': 12232,
#  '้': 366,
#  'ri': 18998,
#  '잗': 6429,
#  '남녀노': 26650,
#  '나오는': 9788,
#  '쿔': 7062,
#  '여건을': 24038,
#  'ent': 11575,
#  '내지': 11064,
#  '擊': 2225,
#  '입에': 14767,
#  '얫': 6138,
#  '것들': 15394,
#  '대교': 26713,
#  '보험이': 18800,
#  '테스트': 19756,
#  '관심도': 19167,
#  '사시는': 21108,
#  '지급': 8614,
#  '남한을': 28027,
#  '부르': 12973,
#  '감한': 16544,
#  '투신': 29909,
#  '강남': 9485,
#  '어떠한': 9849,
#  '주었': 16236,
#  '치열한': 29927,
#  '위협하고': 20880,
#  '서열': 24756,
#  '강력처벌': 28107,
#  '시장으로': 29220,
#  '문제의': 13450,
#  '鳴': 3863,
#  '坦': 1660,
#  '鼓': 3887,
#  '렶': 5016,
#  'จ': 318,
#  '하겠다': 11477,
#  '맞추기': 26406,
#  '지르고': 20333,
#  '살고있는': 12906,
#  '🕺': 8086,
#  '센터에서': 17615,
#  '계십니까': 21763,
#  '闡': 3687,
#  '편에': 16927,
#  '망신': 16387,
#  'ど': 934,
#  '교사': 8742,
#  '롭고': 15695,
#  '시킴': 25001,
#  '衍': 3266,
#  '다릅니다': 14678,
#  '회사로': 19724,
#  '개인사업자': 26037,
#  '아니면': 9138,
#  '시간을': 9147,
#  '없죠': 17697,
#  '㉡': 1125,
#  '는게': 10896,
#  '보안': 11522,
#  '適': 3580,
#  '뿟': 5669,
#  '도무지': 16199,
#  '법을': 8478,
#  '擧': 2229,
#  '지방이': 24885,
#  '경찰관의': 26449,
#  '일뿐': 13837,
#  '폭행이': 24723,
#  '談': 3364,
#  '멸망': 29974,
#  '보셨': 13685,
#  '풔': 7380,
#  '망쳐': 23522,
#  '넘어가면': 25472,
#  '쀼': 5675,
#  '라고요': 11701,
#  '줄고': 17559,
#  '고용주': 24001,
#  '보듯이': 27763,
#  '붙은': 26901,
#  '태양광': 13358,
#  '분담': 16581,
#  '죾': 6577,
#  '소비자의': 22333,
#  '3개': 15155,
#  '접수번호': 29359,
#  '장만': 17353,
#  '흝': 7634,
#  '공권력을': 20890,
#  'ｐ': 7911,
#  '월남': 21256,
#  '김포': 13839,
#  '꾬': 4267,
#  '보기도': 24560,
#  '단독주택': 27862,
#  '편의점': 12565,
#  '*': 11,
#  '공기': 10735,
#  '공무원과': 18780,
#  '작업중지': 28453,
#  '경제적': 10746,
#  '잠을': 12546,
#  '몇천': 21336,
#  '지시로': 29917,
#  '🌻': 7960,
#  '애기': 13235,
#  '보육료': 21386,
#  '대상에': 23251,
#  '호도': 22471,
#  '遇': 3568,
#  '림을': 28749,
#  '한줄': 25567,
#  '坤': 1659,
#  '세게': 22337,
#  '지는': 8376,
#  '시코': 23800,
#  '분리': 11811,
#  'SNS': 12041,
#  '되어있습니다': 13771,
#  '부동산에': 19574,
#  '남녀가': 25103,
#  '딜러': 23959,
#  '나서야': 17436,
#  '키즈': 29171,
#  '면담을': 25715,
#  '토끼': 24443,
#  '소비자는': 27336,
#  '방안이': 14854,
#  '아미': 23009,
#  '이질': 25904,
#  '싨': 5918,
#  '모든것을': 16948,
#  '건의': 10461,
#  '식민': 16629,
#  '취지': 11798,
#  '가보면': 26921,
#  'ň': 158,
#  '증여세': 20622,
#  '세계적인': 17004,
#  '팔이': 19034,
#  '랍시고': 21380,
#  '근무로': 26911,
#  '교수가': 20692,
#  '힘으로': 14682,
#  '김00': 26861,
#  '돈버는': 28242,
#  '갑질과': 23556,
#  '째로': 27541,
#  'ğ': 153,
#  '권이': 10879,
#  '息': 2061,
#  '총살': 26207,
#  '윔': 6334,
#  '조근정훈장': 25056,
#  '적극적': 26884,
#  '가지는': 14835,
#  '나옵': 29370,
#  '눈과': 20195,
#  '강화해야': 21878,
#  '들으면': 26555,
#  '댛': 4603,
#  '붙': 5521,
#  '것인데': 11238,
#  '기와': 14048,
#  '모병': 17341,
#  '고문': 11032,
#  '스마트폰을': 23973,
#  'PS': 20623,
#  '☆': 726,
#  '고통으로': 28763,
#  '않고서는': 23927,
#  '어르': 12076,
#  '효력을': 17606,
#  '승객': 14040,
#  '두개': 26383,
#  '불허': 20320,
#  '말로': 9278,
#  '공인인증': 22540,
#  '청사': 25285,
#  '쐐': 6017,
#  '겁을': 26033,
#  '셫': 5792,
#  '시작으로': 20452,
#  'ы': 263,
#  '큰소리': 22519,
#  '2부': 18287,
#  '그걸로': 22568,
#  '국제적으로': 25752,
#  '혜화': 24047,
#  '되지않은': 29498,
#  '하고있습니다': 10683,
#  '2시': 21694,
#  '비율을': 15117,
#  '1대': 23667,
#  '吏': 7831,
#  '되어서는': 16772,
#  '수사하고': 21006,
#  '➃': 829,
#  '흰': 7644,
#  '힘내': 20827,
#  '스러': 11554,
#  '학생들은': 10855,
#  '원에': 10007,
#  '鎖': 3657,
#  'ᄑ': 391,
#  '졌는데': 18536,
#  '뮌': 5308,
#  '있는건지': 22960,
#  '세워': 10274,
#  '일으킨': 17632,
#  '주민들': 18904,
#  '조장': 11651,
#  '아이스': 16205,
#  '🔵': 8068,
#  '여기저기': 13683,
#  'ore': 24299,
#  '세대는': 22627,
#  '结': 3062,
#  '만연': 16342,
#  '먾': 5193,
#  '국익에': 27784,
#  't': 85,
#  '기준과': 26021,
#  '끱': 4335,
#  '키우는데': 28131,
#  '챌': 6815,
#  '슺': 5899,
#  '을지': 24655,
#  '성차별': 15031,
#  '저는': 8282,
#  '구성원': 16653,
#  '벌이는': 25190,
#  '중국어': 26061,
#  '환': 7551,
#  '거래가': 12759,
#  '폭력배': 26136,
#  '구간': 14032,
#  '꾐': 4264,
#  '되겠': 20294,
#  '장애우': 26961,
#  '실력을': 26204,
#  '군사': 10374,
#  '그래서': 8586,
#  '우주': 21444,
#  '햙': 7468,
#  '부하': 18262,
#  '사라': 9423,
#  '곃': 4011,
#  '쥥': 6608,
#  '무료주차장': 23050,
#  '변함이': 26660,
#  '3년이': 25223,
#  '언론에': 12583,
#  '했음에도': 15430,
#  '寬': 1833,
#  '하나금융': 26512,
#  '매일': 9437,
#  '계속해서': 11923,
#  '영구': 12776,
#  '양': 6128,
#  '훨': 7601,
#  '사관': 12904,
#  '취업이': 18049,
#  '이라서': 12693,
#  '텀': 7156,
#  '악영향을': 20256,
#  '하자가': 26294,
#  '꿩': 4293,
#  '훌륭': 14292,
#  '사지': 16065,
#  '탰': 7140,
#  '의무': 8521,
#  '권력이': 14995,
#  '현안': 25909,
#  '맷': 5171,
#  '돌려주세요': 24201,
#  '보호하기': 19364,
#  'CCTV를': 24365,
#  '성취': 28361,
#  '모습': 9056,
#  '숖': 5836,
#  '대리점': 17885,
#  '瓦': 2767,
#  '않습니까': 10279,
#  '竊': 2952,
#  '적발시': 29034,
#  '빽': 5589,
#  '울산': 12331,
#  '충성': 21490,
#  '박': 5351,
#  '되기': 10186,
#  '김동연': 19806,
#  '나': 4346,
#  '편한': 16864,
#  '외제': 22185,
#  '자유로': 21546,
#  '賴': 3459,
#  '단속을': 13649,
#  '사도': 14147,
#  '롔': 5027,
#  '͢': 202,
#  '편파적인': 29730,
#  '퇴원': 18664,
#  '汗': 2502,
#  '영웅': 18116,
#  '이른': 14115,
#  '미성년자가': 28934,
#  '저에게는': 19423,
#  '법이나': 26773,
#  '단돈': 25630,
#  '제외': 9432,
#  '貰': 3438,
#  '소나': 25826,
#  '시정': 12643,
#  '기를': 8336,
#  '됯': 4707,
#  '다녀': 10477,
#  '한다거나': 27125,
#  '욭': 6281,
#  '오른쪽': 21185,
#  '군인들은': 25144,
#  '신분증을': 24393,
#  '옮겨': 11688,
#  '고등학교에': 19279,
#  '시스템에': 21432,
#  '소득세를': 25623,
#  'ht': 8729,
#  '쓰러': 13906,
#  '그렇다': 14776,
#  '없애기': 29545,
#  '제공할': 26967,
#  '撻': 2222,
#  '춴': 6917,
#  '😱': 8133,
#  '처가': 18662,
#  '雑': 3737,
#  '‒': 462,
#  'KR': 23074,
#  '텝': 7168,
#  '줬': 6597,
#  '관계를': 11856,
#  '국으로': 13807,
#  '입마': 24225,
#  '회원': 12071,
#  '실체를': 27589,
#  '10개월': 19092,
#  '시면서': 22968,
#  '((': 25939,
#  '점으로': 14325,
#  '😭': 8129,
#  '損': 2207,
#  '400': 13451,
#  '个': 1184,
#  'ᅲ': 401,
#  '임대업': 25661,
#  '법앞에': 26253,
#  '«': 103,
#  '돗': 4668,
#  '물을': 9201,
#  '시키는': 9420,
#  '3명의': 28319,
#  '승용차': 24418,
#  '싸우는': 21149,
#  '왜': 6250,
#  '친구와': 24554,
#  '간접': 12206,
#  '봇': 5466,
#  'EA': 20662,
#  '수강': 17409,
#  '☷': 750,
#  '필요할때': 27389,
#  '도와주는': 19026,
#  '탹': 7145,
#  '岸': 1881,
#  '카기': 17765,
#  '보듯': 20458,
#  '청원글': 17355,
#  '彼': 2005,
#  '坊': 1655,
#  '징병제를': 26819,
#  '教': 2250,
#  '방식으로': 11500,
#  '牲': 2707,
#  '쪽에서': 16075,
#  '책임도': 19053,
#  '필요하며': 24722,
#  '윗': 6336,
#  '해가': 12768,
#  '여러번': 13129,
#  '참전용': 22900,
#  '끝내고': 27343,
#  '령': 5019,
#  '만족도': 27306,
#  '⓫': 661,
#  '사정이': 15377,
#  '핸드폰': 11265,
#  '주민들의': 13814,
#  '후진': 14367,
#  '들어가고': 16435,
#  '봐주기': 19707,
#  '결정문': 17540,
#  '뷰': 5536,
#  '15일': 13348,
#  '받아야할': 24111,
#  '폐해': 27287,
#  '악법': 22101,
#  '남는': 14945,
#  '걵': 3961,
#  '보며': 10586,
#  '렿': 5022,
#  '쨕': 6693,
#  '허무': 20574,
#  '김부': 21764,
#  '욉': 6262,
#  '그간': 15296,
#  '투기의': 25663,
#  '현주소': 28897,
#  '희생': 9940,
#  '급을': 10044,
#  '한것입니다': 26082,
#  '늚': 4527,
#  '깂': 4162,
#  '국방부는': 29001,
#  '옰': 6225,
#  '시달리고': 16683,
#  '저번': 21402,
#  '겤': 3989,
#  '큿': 7098,
#  '새마을': 19791,
#  '자식들': 20062,
#  'cm': 17770,
#  '줚': 6594,
#  '낭': 4361,
#  '부작용을': 23516,
#  '시기에': 13177,
#  '편안하게': 22282,
#  '250': 17572,
#  '릍': 5114,
#  '카지노': 18823,
#  '담보대출': 18828,
#  '아줌': 19416,
#  '경제학': 27438,
#  '갑질에': 21374,
#  '\uef58': 7693,
#  '로직스': 27561,
#  '날리고': 27720,
#  '높아': 10931,
#  '형태의': 19510,
#  '휠': 7614,
#  '께서도': 24664,
#  '수한': 12008,
#  '듐': 4747,
#  '맸': 5172,
#  '만들었으면': 24036,
#  '넘기고': 24422,
#  '두가지': 19256,
#  '집없는': 25637,
#  '나라의': 9473,
#  '폭언과': 25404,
#  '인한': 8938,
#  '😙': 8115,
#  '제고': 22087,
#  '퍌': 7300,
#  '적자를': 23826,
#  '팔고': 13655,
#  '점검을': 20853,
#  '로': 5028,
#  '20': 8237,
#  '당파': 28979,
#  '坎': 1656,
#  '핓': 7414,
#  '대기업과': 22401,
#  '號': 3249,
#  '铁': 3667,
#  '세와': 22787,
#  '질문에': 19831,
#  '繫': 3050,
#  '터가': 23860,
#  '률은': 17970,
#  '계의': 15914,
#  'ฉ': 319,
#  '장소에': 22320,
#  '🕒': 8075,
#  '공원조성계획': 21776,
#  'ผ': 332,
#  '비방': 18715,
#  '재현': 25260,
#  '선수의': 14592,
#  '竹': 2961,
#  '하나에': 18397,
#  '고래': 27313,
#  '替': 2337,
#  '呆': 1585,
#  '㉥': 1129,
#  '한해': 15587,
#  'ă': 148,
#  '삼권분립': 20943,
#  '부상': 18301,
#  '기본적인': 11630,
#  '호소': 10704,
#  '선이': 13125,
#  '밤에': 16828,
#  '주둔': 23659,
#  '콤': 7039,
#  'ば': 941,
#  '짋': 6647,
#  '쥐꼬리': 28658,
#  '갇': 3908,
#  '！': 7855,
#  '화가': 8980,
#  '뻔': 5614,
#  '중국에': 13357,
#  '최저시급을': 24143,
#  '봊': 5469,
#  '븉': 5541,
#  '훨씬': 10453,
#  '켘': 7017,
#  '물리치료': 29437,
#  '처한다': 20211,
#  '탣': 7135,
#  '무자격': 23844,
#  '표현의': 15906,
#  '마비': 19718,
#  '髮': 3846,
#  '임금이': 16071,
#  '조롱하는': 29923,
#  '版': 2698,
#  '맞으면': 28980,
#  '점입니다': 17424,
#  '交': 1226,
#  '?..': 24647,
#  '응대': 28007,
#  '변하지': 21441,
#  '진행하고': 16368,
#  '5월에': 29227,
#  '內': 1383,
#  '所': 2137,
#  '멤': 5210,
#  '後': 2011,
#  '외국인이': 16682,
#  '사회복지사': 23324,
#  '민주당': 9401,
#  '되겠지요': 23629,
#  '대북제재': 26597,
#  '券': 1441,
#  '중독': 13260,
#  '가상화폐에': 18785,
#  '춬': 6913,
#  'ㅙ': 1091,
#  '暴': 7846,
#  '어머니와': 23699,
#  '뿌리는': 28752,
#  '등이': 9722,
#  'ง': 317,
#  '구름': 23561,
#  '디젤': 21093,
#  '보험에': 21650,
#  '4': 21,
#  '뺃': 5591,
#  '받았을': 25053,
#  '북에': 24561,
#  '검토': 9390,
#  '건강도': 29426,
#  '料': 2264,
#  '박근혜': 9312,
#  'os': 22379,
#  '릐': 5117,
#  '!!!!': 8535,
#  '연하게': 20257,
#  '다단계': 20766,
#  '효력': 29654,
#  '되었고': 9957,
#  '洪': 2544,
#  '호주': 17294,
#  '보자는': 29301,
#  '줅': 6581,
#  '일어나는': 12621,
#  '되어가고': 17550,
#  '일처리': 25044,
#  '쌓': 5950,
#  '통해서': 10761,
#  '사촌': 23433,
#  '늣': 4532,
#  '검토하여': 22229,
#  '稱': 2936,
#  '시죠': 19933,
#  '주지않고': 27335,
#  '❝': 807,
#  '불안을': 27405,
#  '胃': 3125,
#  '상해': 13929,
#  '휼': 7623,
#  '생각만': 18609,
#  '팜': 7279,
#  '2년간': 17158,
#  '차익을': 25064,
#  '비행': 12345,
#  '벼': 5436,
#  '원래': 10801,
#  '활동하는': 26445,
#  '障': 3725,
#  '등학교': 8962,
#  '⑹': 629,
#  '남자': 9213,
#  '소상공': 21320,
#  '募': 1484,
#  '속은': 27143,
#  '込': 3531,
#  '여유': 12087,
#  '언제나': 13641,
#  '19세': 20527,
#  '縮': 3045,
#  '좁은': 14773,
#  '崎': 1890,
#  '복무기간': 29462,
#  '변태': 29976,
#  'TV': 9727,
#  '자신들을': 28507,
#  '관리계획': 25970,
#  '발생된': 26617,
#  '시간에는': 28013,
#  '주민들은': 15150,
#  '貞': 3427,
#  'ᆨ': 407,
#  '露': 7771,
#  '선에': 16030,
#  '장면': 18248,
#  '불안에': 19627,
#  '거래세': 20270,
#  '노동자의': 16741,
#  '이날': 17064,
#  '2인': 21078,
#  '꼮': 4234,
#  '미분양': 21800,
#  'ク': 986,
#  '늘어': 10155,
#  'ї': 265,
#  '해도': 8432,
#  '스웨덴': 17276,
#  '憲': 2108,
#  '꾸': 4268,
#  '이': 6396,
#  '버리고': 10493,
#  'え': 902,
#  '정신이': 13895,
#  '버렸고': 28167,
#  '계신': 11063,
#  '글에': 14395,
#  '조사관': 23210,
#  '하향': 18054,
#  '두발': 18246,
#  '경찰들의': 14382,
#  '신축': 14983,
#  '필요성': 27669,
#  '픙': 7397,
#  '여타': 26926,
#  '공화': 12482,
#  '조금도': 29501,
#  '잍': 6420,
#  'U': 54,
#  '음주를': 28672,
#  '汀': 2497,
#  '능력도': 20292,
#  '생각하여': 15805,
#  '노력': 9062,
#  '정말이지': 18494,
#  '亦': 1228,
#  '时': 2289,
#  '촛': 6879,
#  '임대주택': 12698,
#  '閃': 3674,
#  '당하면': 19775,
#  '연간': 14446,
#  '뤟': 5080,
#  '12QS': 15086,
#  '탙': 7128,
#  '에너지를': 25025,
#  '의구심이': 20423,
#  '박혀': 26530,
#  '유성': 22899,
#  '해야하는거': 28992,
#  '재활': 15567,
#  '阼': 3698,
#  '으며': 8410,
#  '绝': 3065,
#  '도시': 8902,
#  '대피': 18099,
#  '계정을': 27201,
#  '⇔': 549,
#  '양아': 16088,
#  '광주': 10215,
#  '지어도': 29748,
#  '보내는': 12922,
#  '빙상': 13825,
#  '싵': 5931,
#  '푣': 7364,
#  'IM': 14962,
#  '소리가': 11485,
#  '그만큼': 11218,
#  '끝이': 16034,
#  '오르는데': 25756,
#  '무고죄로': 26001,
#  '일벌백계': 27896,
#  '합니': 29076,
#  '만들어놓은': 28995,
#  '慕': 2095,
#  '조그마한': 23244,
#  '킄': 7100,
#  '푄': 7360,
#  '제기한': 19879,
#  '막막': 14221,
#  '열리는': 20499,
#  '미성년': 10576,
#  '어떤지': 20967,
#  '젲': 6509,
#  '랐습니다': 17209,
#  '하루를': 20167,
#  '바라보는': 18756,
#  '시급합니다': 15413,
#  '우린': 15825,
#  '챙기고': 17418,
#  '쉄': 5858,
#  '74': 21658,
#  '堊': 1675,
#  '개조': 20747,
#  '륲': 5095,
#  '시작했습니다': 15279,
#  '조작하고': 24216,
#  '생명은': 25179,
#  '톰': 7190,
#  '퐐': 7356,
#  '≪': 581,
#  '낧': 4356,
#  '벐': 5408,
#  '😊': 8102,
#  '입법권을': 22682,
#  '사안에': 21569,
#  '요금이': 20620,
#  '가시': 15788,
#  '雜': 3739,
#  '한적이': 21351,
#  '법에서': 18428,
#  '종사': 10490,
#  '보이네요': 29827,
#  '당원': 27978,
#  '속도': 14058,
#  '腹': 3144,
#  'CJ': 21579,
#  '튑': 7234,
#  '訣': 3329,
#  '융': 6352,
#  '일만': 14140,
#  '하더': 21967,
#  '거는': 13370,
#  '여성가족부는': 18984,
#  '받는게': 19747,
#  '원장은': 22817,
#  '헹': 7510,
#  '부담도': 29181,
#  '여도': 19684,
#  '주민번호': 27674,
#  '없지': 15070,
#  '现': 2738,
#  '먽': 5192,
#  '피해보는': 20646,
#  '驥': 3835,
#  '는대': 24030,
#  '개정된': 24950,
#  '줴': 6600,
#  '유무': 23941,
#  '璘': 2758,
#  '명목하에': 21560,
#  '탕진': 29570,
#  '밨': 5368,
#  '경우는': 10970,
#  '骨': 3840,
#  '납부': 9843,
#  '벚': 5417,
#  '항공기': 11753,
#  '权': 2356,
#  '인명': 15393,
#  '도입하여': 24202,
#  '방식에': 27223,
#  '말기': 19980,
#  '바둑': 28948,
#  '시대입니다': 21987,
#  '냡': 4384,
#  '抚': 2153,
#  '群': 3085,
#  '이라니': 15651,
#  '원활': 20460,
#  '건강을': 12653,
#  '图': 1639,
#  '빌려서': 27512,
#  '다름': 10139,
#  '任': 1261,
#  '엘리트': 25478,
#  '池': 2506,
#  'as': 8213,
#  '직면': 22210,
#  '기자들': 25457,
#  '이적': 27844,
#  '친절한': 28659,
#  '제목': 11196,
#  '드로': 19938,
#  '칭': 6961,
#  '랑이': 27722,
#  '간다': 12231,
#  '속도를': 21024,
#  '거로': 21779,
#  '誓': 3349,
#  '정의로운': 12719,
#  '최종': 11168,
#  '휘둘': 20523,
#  '이대로': 11728,
#  'ers': 27366,
#  '잘못은': 20616,
#  '형법': 15675,
#  '발전에': 14097,
#  '000': 8741,
#  '제작': 11850,
#  'for': 18329,
#  '시진핑': 26732,
#  '아끼고': 23918,
#  '꽐': 4252,
#  '좉': 6542,
#  '일용': 13215,
#  '왷': 6257,
#  '펜스': 26806,
#  '동지': 28649,
#  '켭': 7027,
#  'DMZ': 26731,
#  '나지': 11410,
#  '지정재판': 14484,
#  '지원이': 12278,
#  '노회': 21471,
#  '아직까지': 13244,
#  '🐙': 7995,
#  '한국인': 12882,
#  '입학정': 14998,
#  '딍': 4776,
#  '도없고': 28177,
#  'â': 127,
#  '하셨던': 19781,
#  '틀림': 21369,
#  '인지도': 15903,
#  '학부모입니다': 27303,
#  '얍': 6124,
#  '남성만': 27911,
#  '때의': 20665,
#  '경쟁력': 15300,
#  '效': 2241,
#  '이때': 14342,
#  '사람한테': 20237,
#  '휴교': 15999,
#  'ye': 25250,
#  '말과': 14378,
#  '공영방송': 26070,
#  '論': 3366,
#  '스의': 20937,
#  '고발': 9418,
#  'LSD': 15344,
#  '군대를': 11736,
#  '참여한': 23029,
#  '만듭니다': 15972,
#  '피시': 19441,
#  '결론을': 20044,
#  '초등생': 24993,
#  '벢': 5425,
#  '조그만': 18861,
#  '틜': 7259,
#  '이관': 17736,
#  '6만': 27899,
#  '지속적인': 15369,
#  '삼성바이오로': 15520,
#  'う': 900,
#  '촟': 6882,
#  '대한민국에는': 24721,
#  '복지부동': 29355,
#  '피의자가': 22766,
#  '증조': 26109,
#  '꽘': 4253,
#  '겨운': 23149,
#  '더라도': 8869,
#  '∠': 569,
#  '비용이': 11432,
#  '되어야합니다': 17259,
#  ...}

# %%
# 테스트 문장
sports_txt = "프리미어리그 역대 개인 최다골 기록을 보유하고 있는 시어러가 손흥민의 골 결정력을 재차 극찬했다."
petition_txt = "이 글을 쓴 이유는 다름아닌 '전안법'시행 반대를 주장하기 위해서입니다. 먼저, '전안법'은 전기용품 및 생활용품을 판매하는 업체에서 KC인증마크를 의무적으로 받는 것입니다."
comment_txt = "멋진 식사를 즐기기에 좋은 장소 - 채식 메뉴가 정말 훌륭했습니다. 당근 케이크는 아마도 내가 먹어본 디저트 중 최고였을 거예요."

# %%
# text -> token 화
token_output = tokenizer.encode(sports_txt)
token_output
# Out:
# Encoding(num_tokens=25, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])

# %%
# 토큰 - 단어
token_output.tokens
# Out:
# ['프리미',
#  '어리',
#  '그',
#  '역대',
#  '개인',
#  '최',
#  '다',
#  '골',
#  '기록을',
#  '보유하고',
#  '있는',
#  '시',
#  '어',
#  '러',
#  '가',
#  '손흥민',
#  '의',
#  '골',
#  '결정',
#  '력을',
#  '재차',
#  '극',
#  '찬',
#  '했다',
#  '.']

# %%
# 토큰 - 토큰 id(정수)
token_output.ids
# Out:
# [17894,
#  11085,
#  4128,
#  14043,
#  8414,
#  6891,
#  4563,
#  4027,
#  16508,
#  17816,
#  8219,
#  5908,
#  6140,
#  4980,
#  3902,
#  14807,
#  6384,
#  4027,
#  8940,
#  8644,
#  22240,
#  4129,
#  6795,
#  8565,
#  15]

# %%
output = tokenizer.encode(petition_txt)
print(output.tokens)
# Out:
# ['이', '글을', '쓴', '이유는', '다름', '아닌', "'", '전', '안', '법', "'", '시행', '반대를', '주장', '하기', '위해서', '입니다', '.', '먼저', ',', "'", '전', '안', '법', "'", '은', '전기', '용품', '및', '생활', '용', '품을', '판매하는', '업체에서', 'K', 'C', '인증', '마크', '를', '의무적으로', '받는', '것입니다', '.']

# %%
print(output.ids)
# Out:
# [6396, 8577, 6044, 9246, 10139, 8323, 8, 6476, 6073, 5412, 8, 8656, 16307, 8953, 8301, 8580, 8212, 15, 8855, 13, 8, 6476, 6073, 5412, 8, 6360, 9353, 15879, 5345, 8437, 6278, 11250, 18121, 15638, 44, 36, 10497, 16702, 5101, 13014, 8546, 8299, 15]

# %%
# offsets[토큰리스트의 index]
output.offsets[3] # 3번 index : ('이유는', 9246) -> 입력 문서(string)에 어디에 위치하는지 반환. 7번 index ~ 9번 index
# Out:
# (7, 10)

# %%
tokenizer.token_to_id("이유") # 입력값이 몇번째 토큰인지 반환.
tokenizer.id_to_token(8341) # 입력값에 해당하는 id의 토큰내용 반환.
# Out:
# '이유'

# %%
ids = [100, 8231, 8341, 20, 700, 1238]
decode_output = tokenizer.decode(ids) # 토큰 id로 구성된 리스트를 문장(str)으로 decode.
decode_output
# Out:
# '¥ 니까 이유 3 ▶ 什'

# %%
tokenizer.decode(output.ids)
# Out:
# "이 글을 쓴 이유는 다름 아닌 ' 전 안 법 ' 시행 반대를 주장 하기 위해서 입니다 . 먼저 , ' 전 안 법 ' 은 전기 용품 및 생활 용 품을 판매하는 업체에서 K C 인증 마크 를 의무적으로 받는 것입니다 ."

# %% [markdown]
# ## Word Piece 모델 학습

# %%
from tokenizers import Tokenizer
from tokenizers.models import WordPiece
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.trainers import WordPieceTrainer

# tokenizer 생성
tokenizer2 = Tokenizer(WordPiece(unk_token='[UNK]'))
# Pre tokenizer
tokenizer2.pre_tokenizers = Whitespace
# Trainer 생성
trainer = WordPieceTrainer(
    vocab_size=20000,
    special_tokens=['[UNK]', '[PAD]', '[SEP]', '[SOS]', '[EOS]'],
    min_frequency=10
)

# %%
import time
# 학습
s = time.time()
tokenizer2.train(['data/petitions_corpus.txt'],trainer=trainer)
e = time.time()
print(f"걸린 시간 : {e-s}초")

# %%
tokenizer2.save("saved_models/petitions_wordpiece.json")

# %%
load_tokenizer2 = Tokenizer.from_file("saved_models/petitions_wordpiece.json")

# %%
tokenizer2.get_vocab_size()

# %%
tokenizer2.token_to_id('안녕하세요')

# %%
tokenizer2.id_to_token('15453')

# %%
output = tokenizer2.encode(comment_txt)

# %%
output.ids

# %%
output.tokens

# %%
tokenizer2.decode(output.ids)

# %%
comment_txt

# %%
## Unigram 모델 학습

# %%
from tokenizers import Tokenizer
from tokenizers.models import Unigram
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.trainers import UnigramTrainer

# tokenizer 생성
tokenizer3 = Tokenizer(Unigram())
# Pre tokenizer
tokenizer3.pre_tokenizers = Whitespace
# Trainer 생성
trainer = UnigramTrainer(
    vocab_size=10000,
    special_tokens=['[UNK]', '[PAD]', '[SEP]', '[SOS]', '[EOS]'],
    min_frequency=10
)

# %%
import time
# 학습
s = time.time()
tokenizer3.train(['data/petitions_corpus.txt'],trainer=trainer)
e = time.time()
print(f"걸린 시간 : {e-s}초")
# Out:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
tokenizer3.save("saved_models/petitions_unigram.json")

# %%
tokenizer.token_to_id('안녕하세요')

# %%
tokenizer3.id_to_token()

# %%
output = tokenizer3.encode(comment_txt)
output.tokens

# %%
output.ids

# %%
output.tokens

# %%
tokenizer3.decode(output.ids)
# " ".join(output.tokens)
