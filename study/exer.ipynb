# %%
def solution(wallet, bill):
    answer = 0
    return answer

def big(a,b):
    if (a>=b):
        return a
    else:
        return b

bill = [10,20]

big(bill[0],bill[1])
# Out:
#   Cell In[4], line 7
#     return %a
#            ^
# SyntaxError: invalid syntax
